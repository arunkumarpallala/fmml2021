# %% [markdown]
# <a href="https://colab.research.google.com/github/arunkumarpallala/fmml2021/blob/main/Module8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-17 16:20:42--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   144MB/s    in 0.5s
#
# 2022-06-17 16:20:43 (144 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3174 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3244 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 11  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3268    1312.6965v1  Using supervised machine learning approaches t...  stat
# 30128  1711.07568v1  To denoise a reference patch, the Non-Local-Me...    cs
# 16532  1703.09817v3  A significant source of errors in Automatic Sp...    cs
# 29540  1709.06841v2  We propose a novel monocular visual odometry (...    cs
# 32922  1511.05371v1  A new algorithm named EXPected Similarity Esti...    cs
# ...             ...                                                ...   ...
# 22884  1710.01406v2  This work constructs a hypothesis test for det...  stat
# 22745  1705.08933v2  Gaussian processes (GPs) are a good choice for...  stat
# 28031  1705.04272v1  The experimental results of improved underwate...    cs
# 29126  1708.04907v2  While 3D reconstruction is a well-established ...    cs
# 33014  1712.07834v3  We propose DropMax, a stochastic version of so...    cs
#
#                                                    title  year  \
# 3268   An Unsupervised Approach for Automatic Activit...  2013
# 30128  On Nearest Neighbors in Non Local Means Denoising  2017
# 16532  Learning Similarity Functions for Pronunciatio...  2017
# 29540  UnDeepVO: Monocular Visual Odometry through Un...  2017
# 32922  Constant Time EXPected Similarity Estimation u...  2015
# ...                                                  ...   ...
# 22884  Robust Hypothesis Test for Nonlinear Effect wi...  2017
# 22745  Doubly Stochastic Variational Inference for De...  2017
# 28031  Improved underwater image enhancement algorith...  2017
# 29126  Multi-View Stereo with Single-View Semantic Me...  2017
# 33014              DropMax: Adaptive Variational Softmax  2017
#
#                                                 keywords
# 3268   [accelerometers, unsupervised, unsupervised, a...
# 30128       [computational, analytically, computational]
# 16532  [pronunciation, conversational, pronunciations...
# 29540         [unsupervised, specifically, unsupervised]
# 32922  [distribution, computational, implications, op...
# ...                                                  ...
# 22884     [specification, consequences, hyperparameters]
# 22745  [approximation, generalisations, independence,...
# 28031  [experimental, differential, incorporating, im...
# 29126  [reconstruction, reconstruction, reconstructio...
# 33014  [probabilities, specifically, probabilities, r...
#
# [5134 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3268     [accelerometers, unsupervised, unsupervised, a...
# 30128         [computational, analytically, computational]
# 16532    [pronunciation, conversational, pronunciations...
# 29540           [unsupervised, specifically, unsupervised]
# 32922    [distribution, computational, implications, op...
#                                ...
# 9677     [decomposition, multidimensional, classificati...
# 6095        [optimization, interpretation, approximations]
# 10607    [approximating, multidimensional, distribution...
# 11624                      [characteristics, underpowered]
# 22781    [measurements, neighborhood, unsupervised, pho...
# Name: keywords, Length: 6418, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 2898 words.
# Out of those 1271 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="9e52afd8-5a32-4962-81a1-b276214695e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9e52afd8-5a32-4962-81a1-b276214695e9")) {                    Plotly.newPlot(                        "9e52afd8-5a32-4962-81a1-b276214695e9",                        [{"x":["multidimensional","maximization","acceleration","segmentation","experimental","accelerometers","unsupervised","classification","computational","analytically","conversational","pronunciations","pronunciation","neighborhoods","specifically","distribution","optimization","implications","deterministic","approximation","architecture","configurations","localisation","respectively","contribution","convolutional","representations","conventional","intentionally","sequentially","unintentionally","relationships","differentiable","cardiovascular","manipulating","shortcomings","corresponding","introduction","approximated","factorization","applicability","construction","minimization","subsequently","probabilistic","effectiveness","demonstrated","simultaneously","implementation","advantageous","differentiating","substantiate","representation","dimensionality","substantially","incorporating","automatically","significantly","successfully","interactions","uncertainties","differentiation","fundamentally","inhomogeneous","identification","generalizability","computationally","regularization","semidefinite","improvements","perturbations","augmentation","unfortunately","transcription","necessitates","disentangling","investigates","uninformative","observations","investigated","hierarchical","measurements","characterize","difficulties","nonparametric","intermediate","surprisingly","conservative","normalization","approximations","mathematical","rediscovering","enhancements","architectural","visualization","correspondence","environments","contributions","descriptions","localization","understanding","capabilities","modification","satisfaction","generalization","straightforward","combinatorial","combinations","comprehension","technologies","dictionaries","intelligence","standardized","reparameterization","independence","parallelization","parallelizable","independencies","parameterize","extrapolating","applications","decomposition","characterizing","differentiability","separability","transformations","comprehensive","constructing","bidirectional","observational","discrimination","multivariate","relationship","dramatically","transmission","outperformed","aforementioned","theoretically","neighborhood","eigenvectors","discriminant","particularly","approximates","transforming","reconstruction","functionally","characterization","robustification","explorations","commonalities","summarization","dissimilarity","traditionally","recommendations","recommendation","collaborative","parametrized","technological","consistently","investigating","interpretability","approximately","interpretable","understandable","interpretation","interpreting","consideration","thresholding","misclassified","responsibility","generalisation","increasingly","transportation","intersection","preservation","consequences","multilingual","similarities","parameterized","representable","approximating","constructions","catastrophic","discriminative","dependencies","bioinformatics","surroundings","complementary","correlations","insufficient","dissertation","distributions","accelerating","coefficients","specializing","phonetically","incorporates","partitioning","perspectives","accommodates"],"y":[10,28,11,187,316,1,148,487,257,16,14,3,7,10,159,176,301,27,30,102,219,24,6,84,63,352,221,101,3,13,0,73,20,2,8,17,128,31,23,35,41,57,48,20,137,192,85,117,138,5,4,1,320,50,32,55,180,244,94,68,14,2,4,3,103,3,74,73,6,120,18,17,31,8,2,4,15,2,60,43,105,44,50,24,13,32,30,6, ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (1271,), (1271, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7624610591900312

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Continuous</span> <span style=''>Implicit</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>Authentication</span> <span style=''>for</span> <span style=''>Mobile</span> <span style=''>Devices</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Adaptive</span> <span style=''>Neuro</span> <span style=''>Fuzzy</span> <span style=''>Inference</span> <span style=''>System</span> <br/><br/><span style=''>As</span> <span style=''>mobile</span> <span style=''>devices</span> <span style=''>have</span> <span style=''>become</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>indispensable</span> <span style=''>in</span> <span style=''>modern</span> <span style=''>life</span> <span style=''>mobile</span> <span style=''>security</span> <span style=''>is</span> <span style=''>becoming</span> <span style=''>much</span> <span style=''>more</span> <span style=''>important</span> <span style=''>Traditional</span> <span style=''>password</span> <span style=''>or</span> <span style=''>PIN</span> <span style=''>like</span> <span style=''>point</span> <span style=''>of</span> <span style=''>entry</span> <span style=''>security</span> <span style=''>measures</span> <span style=''>score</span> <span style=''>low</span> <span style=''>on</span> <span style=''>usability</span> <span style=''>and</span> <span style=''>are</span> <span style=''>vulnerable</span> <span style=''>to</span> <span style=''>brute</span> <span style=''>force</span> <span style=''>and</span> <span style=''>other</span> <span style=''>types</span> <span style=''>of</span> <span style=''>attacks</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>improve</span> <span style=''>mobile</span> <span style=''>security</span> <span style=''>an</span> <span style=''>adaptive</span> <span style=''>neuro</span> <span style=''>fuzzy</span> <span style=''>inference</span> <span style=''>system(ANFIS)</span> <span style=''>based</span> <span style=''>implicit</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>authentication</span> <span style=''>system</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>to</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>authentication</span> <span style=''>in</span> <span style=''>a</span> <span style=''>continuous</span> <span style=''>and</span> <span style=''>transparent</span> <span style=''>mannerTo</span> <span style=''>illustrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applicability</span> <span style=''>and</span> <span style=''>capability</span> <span style=''>of</span> <span style=''>ANFIS</span> <span style=''>in</span> <span style=''>our</span> <span style=''>implicit</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>authentication</span> <span style=''>system</span> <span style=''>experiments</span> <span style=''>were</span> <span style=''>conducted</span> <span style=''>on</span> <span style=''>behavioural</span> <span style=''>data</span> <span style=''>collected</span> <span style=''>for</span> <span style=''>up</span> <span style=''>to</span> <span style=''>12</span> <span style=''>weeks</span> <span style=''>from</span> <span style=''>different</span> <span style=''>Android</span> <span style=''>users</span> <span style=''>The</span> <span style=''>ability</span> <span style=''>of</span> <span style=''>the</span> <span style=''>ANFIS</span> <span style=''>based</span> <span style=''>system</span> <span style=''>to</span> <span style=''>detect</span> <span style=''>an</span> <span style=''>adversary</span> <span style=''>is</span> <span style=''>also</span> <span style=''>tested</span> <span style=''>with</span> <span style=''>scenarios</span> <span style=''>involving</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>MCMC</span> <span style=''>sampling</span> <span style=''>algorithms</span> <span style=''>on</span> <span style=''>polytopes</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>analyze</span> <span style=''>two</span> <span style=''>new</span> <span style=''>MCMC</span> <span style=''>sampling</span> <span style=''>algorithms</span> <span style=''>the</span> <span style=''>Vaidya</span> <span style=''>walk</span> <span style=''>and</span> <span style=''>the</span> <span style=''>John</span> <span style=''>walk</span> <span style=''>for</span> <span style=''>generating</span> <span style=''>samples</span> <span style=''>from</span> <span style=''>the</span> <span style=''>uniform</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>a</span> <span style=''>polytope</span> <span style=''>Both</span> <span style=''>random</span> <span style=''>walks</span> <span style=''>are</span> <span style=''>sampling</span> <span style=''>algorithms</span> <span style=''>derived</span> <span style=''>from</span> <span style=''>interior</span> <span style=''>point</span> <span style=''>methods</span> <span style=''>The</span> <span style=''>former</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>volumetric</span> <span style=''>logarithmic</span> <span style=''>barrier</span> <span style=''>introduced</span> <span style=''>by</span> <span style=''>Vaidya</span> <span style=''>whereas</span> <span style=''>the</span> <span style=''>latter</span> <span style=''>uses</span> <span style=''>Johns</span> <span style=''>ellipsoids</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>Vaidya</span> <span style=''>walk</span> <span style=''>mixes</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significantly</span> <span style=''>fewer</span> <span style=''>steps</span> <span style=''>than</span> <span style=''>the</span> <span style=''>logarithmic</span> <span style=''>barrier</span> <span style=''>based</span> <span style=''>Dikin</span> <span style=''>walk</span> <span style=''>studied</span> <span style=''>in</span> <span style=''>past</span> <span style=''>work</span> <span style=''>For</span> <span style=''>a</span> <span style=''>polytope</span> <span style=''>in</span> <span style=''>mathbbRd</span> <span style=''>defined</span> <span style=''>by</span> <span style=''>n</span> <span style=''>d</span> <span style=''>linear</span> <span style=''>constraints</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>mixing</span> <span style=''>time</span> <span style=''>from</span> <span style=''>a</span> <span style=''>warm</span> <span style=''>start</span> <span style=''>is</span> <span style=''>bounded</span> <span style=''>as</span> <span style=''>mathcalO(n05d15)</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>the</span> <span style=''>mathcalO(nd)</span> <span style=''>mixing</span> <span style=''>time</span> <span style=''>bound</span> <span style=''>for</span> <span style=''>the</span> <span style=''>Dikin</span> <span style=''>walk</span> <span style=''>The</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>each</span> <span style=''>step</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Vaidya</span> <span style=''>walk</span> <span style=''>is</span> <span style=''>of</span> <span style=''>the</span> <span style=''>same</span> <span style=''>order</span> <span style=''>as</span> <span style=''>the</span> <span style=''>Dikin</span> <span style=''>walk</span> <span style=''>and</span> <span style=''>at</span> <span style=''>most</span> <span style=''>twice</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fourier</span> <span style=''>PCA</span> <span style=''>and</span> <span style=''>Robust</span> <span style=''>Tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Decomposition</span> <br/><br/><span style=''>Fourier</span> <span style=''>PCA</span> <span style=''>is</span> <span style=''>Principal</span> <span style=''>Component</span> <span style=''>Analysis</span> <span style=''>of</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>obtained</span> <span style=''>from</span> <span style=''>higher</span> <span style=''>order</span> <span style=''>derivatives</span> <span style=''>of</span> <span style=''>the</span> <span style=''>logarithm</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Fourier</span> <span style=''>transform</span> <span style=''>of</span> <span style=''>a</span> <span style=''>distributionWe</span> <span style=''>make</span> <span style=''>this</span> <span style=''>method</span> <span style=''>algorithmic</span> <span style=''>by</span> <span style=''>developing</span> <span style=''>a</span> <span style=''>tensor</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>decomposition</span> <span style=''>method</span> <span style=''>for</span> <span style=''>a</span> <span style=''>pair</span> <span style=''>of</span> <span style=''>tensors</span> <span style=''>sharing</span> <span style=''>the</span> <span style=''>same</span> <span style=''>vectors</span> <span style=''>in</span> <span style=''>rank</span> <span style=''>1</span> <span style='background-color:rgba(255, 0, 0, 0.5172413793103449);'>decompositions</span> <span style=''>Our</span> <span style=''>main</span> <span style=''>application</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>provably</span> <span style=''>polynomial</span> <span style=''>time</span> <span style=''>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.39999999999999997);'>underdetermined</span> <span style=''>ICA</span> <span style=''>ie</span> <span style=''>learning</span> <span style=''>an</span> <span style=''>n</span> <span style=''>times</span> <span style=''>m</span> <span style=''>matrix</span> <span style=''>A</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.5555555555555556);'>observations</span> <span style=''>yAx</span> <span style=''>where</span> <span style=''>x</span> <span style=''>is</span> <span style=''>drawn</span> <span style=''>from</span> <span style=''>an</span> <span style=''>unknown</span> <span style=''>product</span> <span style='background-color:rgba(255, 0, 0, 0.4642313546423136);'>distribution</span> <span style=''>with</span> <span style=''>arbitrary</span> <span style=''>non</span> <span style=''>Gaussian</span> <span style=''>components</span> <span style=''>The</span> <span style=''>number</span> <span style=''>of</span> <span style=''>component</span> <span style='background-color:rgba(255, 0, 0, 0.5366430260047281);'>distributions</span> <span style=''>m</span> <span style=''>can</span> <span style=''>be</span> <span style=''>arbitrarily</span> <span style=''>higher</span> <span style=''>than</span> <span style=''>the</span> <span style=''>dimension</span> <span style=''>n</span> <span style=''>and</span> <span style=''>the</span> <span style=''>columns</span> <span style=''>of</span> <span style=''>A</span> <span style=''>only</span> <span style=''>need</span> <span style=''>to</span> <span style=''>satisfy</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>and</span> <span style=''>efficiently</span> <span style=''>verifiable</span> <span style=''>nondegeneracy</span> <span style=''>condition</span> <span style=''>As</span> <span style=''>a</span> <span style=''>second</span> <span style=''>application</span> <span style=''>we</span> <span style=''>give</span> <span style=''>an</span> <span style=''>alte ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Integrated</span> <span style=''>perception</span> <span style=''>with</span> <span style=''>recurrent</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>neural</span> <span style=''>networks</span> <br/><br/><span style=''>Modern</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discriminative</span> <span style=''>predictors</span> <span style=''>have</span> <span style=''>been</span> <span style=''>shown</span> <span style=''>to</span> <span style=''>match</span> <span style=''>natural</span> <span style=''>intelligences</span> <span style=''>in</span> <span style=''>specific</span> <span style=''>perceptual</span> <span style=''>tasks</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>object</span> <span style=''>and</span> <span style=''>part</span> <span style=''>detection</span> <span style=''>boundary</span> <span style=''>extraction</span> <span style=''>etc</span> <span style=''>However</span> <span style=''>a</span> <span style=''>major</span> <span style=''>advantage</span> <span style=''>that</span> <span style=''>natural</span> <span style=''>intelligences</span> <span style=''>still</span> <span style=''>have</span> <span style=''>is</span> <span style=''>that</span> <span style=''>they</span> <span style=''>work</span> <span style=''>well</span> <span style=''>for</span> <span style=''>all</span> <span style=''>perceptual</span> <span style=''>problems</span> <span style=''>together</span> <span style=''>solving</span> <span style=''>them</span> <span style=''>efficiently</span> <span style=''>and</span> <span style=''>coherently</span> <span style=''>in</span> <span style=''>an</span> <span style=''>integrated</span> <span style=''>manner</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>some</span> <span style=''>of</span> <span style=''>these</span> <span style=''>advantages</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>perception</span> <span style=''>we</span> <span style=''>ask</span> <span style=''>two</span> <span style=''>questions</span> <span style=''>whether</span> <span style=''>deep</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>universal</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representations</span> <span style=''>useful</span> <span style=''>not</span> <span style=''>only</span> <span style=''>for</span> <span style=''>a</span> <span style=''>single</span> <span style=''>task</span> <span style=''>but</span> <span style=''>for</span> <span style=''>all</span> <span style=''>of</span> <span style=''>them</span> <span style=''>and</span> <span style=''>how</span> <span style=''>the</span> <span style=''>solutions</span> <span style=''>to</span> <span style=''>the</span> <span style=''>different</span> <span style=''>tasks</span> <span style=''>can</span> <span style=''>be</span> <span style=''>integrated</span> <span style=''>in</span> <span style=''>this</span> <span style=''>framework</span> <span style=''>We</span> <span style=''>answer</span> <span style=''>by</span> <span style=''>proposing</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architecture</span> <span style=''>which</span> <span style=''>we</span> <span style=''>call</span> <span style=''>MultiNet</span> <span style=''>in</span> <span style=''>which</span> <span style=''>not</span> <span style=''>only</span> <span style=''>deep</span> <span style=''>image</span> <span style=''>features</span> <span style=''>are</span> <span style=''>shared</span> <span style=''>between</span> <span style=''>tasks</span> <span style=''>but</span> <span style=''>where</span> <span style=''>tasks</s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	localization (0.02580140734949179)
# 	discriminative (0.039093041438623924)
# 	intelligence (0.033620015637216574)
# 	automatically (0.07036747458952307)
# 	representations (0.08639562157935887)
# 	experimental (0.1235340109460516)
# 	representation (0.12509773260359655)
# 	architecture (0.0856137607505864)
# 	segmentation (0.07310398749022674)
# 	convolutional (0.1376075058639562)
#
# Some Statistics words are:
# 	applications (0.18517080745341616)
# 	multivariate (0.05007763975155279)
# 	computationally (0.07608695652173914)
# 	regularization (0.0764751552795031)
# 	nonparametric (0.05822981366459627)
# 	observations (0.08152173913043478)
# 	approximation (0.09937888198757763)
# 	optimization (0.1793478260869565)
# 	distributions (0.12616459627329193)
# 	distribution (0.18672360248447206)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="80528561-03f4-46bc-bc19-38bd48a9930c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80528561-03f4-46bc-bc19-38bd48a9930c")) {                    Plotly.newPlot(                        "80528561-03f4-46bc-bc19-38bd48a9930c",                        [{"x":["multidimensional","maximization","acceleration","segmentation","experimental","accelerometers","unsupervised","classification","computational","analytically","conversational","pronunciations","pronunciation","neighborhoods","specifically","distribution","optimization","implications","deterministic","approximation","architecture","configurations","localisation","respectively","contribution","convolutional","representations","conventional","intentionally","sequentially","unintentionally","relationships","differentiable","cardiovascular","manipulating","shortcomings","corresponding","introduction","approximated","factorization","applicability","construction","minimization","subsequently","probabilistic","effectiveness","demonstrated","simultaneously","implementation","advantageous","differentiating","substantiate","representation","dimensionality","substantially","incorporating","automatically","significantly","successfully","interactions","uncertainties","differentiation","fundamentally","inhomogeneous","identification","generalizability","computationally","regularization","semidefinite","improvements","perturbations","augmentation","unfortunately","transcription","necessitates","disentangling","investigates","uninformative","observations","investigated","hierarchical","measurements","characterize","difficulties","nonparametric","intermediate","surprisingly","conservative","normalization","approximations","mathematical","rediscovering","enhancements","architectural","visualization","correspondence","environments","contributions","descriptions","localization","understanding","capabilities","modification","satisfaction","generalization","straightforward","combinatorial","combinations","comprehension","technologies","dictionaries","intelligence","standardized","reparameterization","independence","parallelization","parallelizable","independencies","parameterize","extrapolating","applications","decomposition","characterizing","differentiability","separability","transformations","comprehensive","constructing","bidirectional","observational","discrimination","multivariate","relationship","dramatically","transmission","outperformed","aforementioned","theoretically","neighborhood","eigenvectors","discriminant","particularly","approximates","transforming","reconstruction","functionally","characterization","robustification","explorations","commonalities","summarization","dissimilarity","traditionally","recommendations","recommendation","collaborative","parametrized","technological","consistently","investigating","interpretability","approximately","interpretable","understandable","interpretation","interpreting","consideration","thresholding","misclassified","responsibility","generalisation","increasingly","transportation","intersection","preservation","consequences","multilingual","similarities","parameterized","representable","approximating","constructions","catastrophic","discriminative","dependencies","bioinformatics","surroundings","complementary","correlations","insufficient","dissertation","distributions","accelerating","coefficients","specializing","phonetically","incorporates","partitioning","perspectives","accommodates","unbiasedness","reinforcement","communication","characteristic","architectures","backpropagation","incorporated","deformations","experimentally","displacement","progressively","inconsistency","definiteness","transformation","communicated","prohibitively","significance","qu ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	unintentionally
# 	robustification
# 	explorations
# 	commonalities
# 	dissertation
# 	definiteness
# 	rehabilitation
# 	instantiating
# 	identifiability
# 	inappropriately
# 	gaussianization
# 	approachable
# 	documentation
# 	semiparametric
# 	advertisement
# 	underpinning
# 	hamiltonians
# 	compensating
# 	unbalancedness
# 	crowdworkers
# Some words which never appear in Statistics papers:
# 	conversational
# 	pronunciation
# 	necessitates
# 	responsibility
# 	phonetically
# 	propositional
# 	configurable
# 	diversification
# 	interrogative
# 	unregistered
# 	evolvability
# 	indefinitely
# 	universities
# 	disambiguation
# 	metaheuristic
# 	illumination
# 	paleographic
# 	syntactically
# 	coevolutionary
# 	reconfigurable

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.699456179941549e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7585669781931464
